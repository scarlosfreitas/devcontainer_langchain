# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join("../src")))

# %%
from ultimasnoticias.scraper import Noticias
from ultimasnoticias.storage import Storage
from ultimasnoticias.telegram import Telegram

# %% [markdown]
# # Teste do Scraper

# %%
nav = Noticias()
nav.driver.maximize_window()
# Out:
# Sessão iniciada com sucesso.

# %%
nav.busca_lista(lista_uf=['sp','mt','rn','pa','df','go','ce'],fonte='gran',verbose=False)
nav.busca_lista(lista_uf=['go','pi','sp','mt'],fonte='fcc_linkarquivo',verbose=False)
nav.busca_lista(lista_uf=['go','pi','sp','mt'],fonte='fcc_publicacao',verbose=False)

# %%
nav.busca_lista(lista_uf=['rn'],fonte='cebraspe',verbose=False)

# %%
nav.busca_lista(fonte='cebraspe_novos',verbose=False)

# %% [markdown]
# # Ultimas Noticias

# %%
db = Storage(verbose=True)
tg = Telegram()
# Out:
# Storage inicializado: /workspace/data/noticias/banco_noticias.db

# %%
def atualiza_e_envia(fonte):
    print(fonte)
    resultados = db.last(5,fonte=fonte,verbose=False)    
    [print(r["enviada"],r["txcompleto"]) for r in resultados ]
    tg.envia_resultados(resultados,fonte=fonte)

# %% [markdown]
# #### gran

# %%
atualiza_e_envia('gran')
# Out:
# gran
# 1 02 de março de 2026: gabarito preliminar disponível

# %% [markdown]
# #### fcc_linkarquivo

# %%
atualiza_e_envia('fcc_linkarquivo')
# Out:
# fcc_linkarquivo
# 0 Divulgação dos Gabaritos e Provas
# 0 Edital nº 14/2026 - De Divulgação do Resultado da Avaliação Biospsicossocial e da Comissão de Heteroidentificação
# 0 Resultado da Comissão de Heteroidentificação
# 0 Resultado da Avaliação Biopsicossocial

# %% [markdown]
# #### fcc_publicacao

# %%
resultados = db.last(5,fonte='fcc_publicacao',verbose=False)    
[print(r["txcompleto"]) for r in resultados ]
# Out:
# Edital nº 14/2026 - De Divulgação do Resultado da Avaliação Biospsicossocial e da Comissão de Heteroidentificação publicado no Diário Oficial do Estado do Piauí, edição de 26/02/2026.
# [None]

# %% [markdown]
# #### cebraspe

# %%
resultados = db.last(5,fonte='cebraspe',verbose=False)    
[print(r["txcompleto"]) for r in resultados ]
# Out:
# 02/03/2026 10:00
# Consulta individual à situação final na solicitação de atendimento especializado
# 02/03/2026 10:00
# Relação final dos candidatos com a inscrição deferida – Vlibras
# 02/03/2026 10:00
# Relação final dos candidatos com a inscrição deferida
# [None, None, None]

# %% [markdown]
# #### GRAN

# %%
resultados = db.last(5,fonte='cebraspe_novos',verbose=False)
[print(r["txcompleto"]) for r in resultados ]
# Out:
# SEPLAG AL 26 ESPECIALISTA
# [None]

# %%
# Out:
# SEPLAG AL 26 ESPECIALISTA
# [None]

# %% [markdown]
# # Teste do Parser

# %%
from ultimasnoticias.parser import BaseParser as bp
from ultimasnoticias.parser import NoticiasParser as np

# %%
# np.cebraspe_list_text(nav.driver)
list_text = np.list_text(nav.driver,fonte='cebraspe_novos')
r = np.rec_cebraspe_novos_from_text(list_text[0])
db.read(hashid='b55d1f8896dd9b929d465128f2fe19a6c44d9fb30d6359586521b23d805dc860')
# Out:
# []

# %% [markdown]
# # Teste do Telegram

# %%
# tg_envia_resultados(resultados,fonte='gran_noticias')
# tg_envia_resultados(resultados,fonte='fcc_linkarquivo')
# tg_envia_resultados(resultados,fonte='fcc_publicacao')
# tg_envia_resultados(resultados,fonte='cebraspe')
tg.envia_resultados(resultados,fonte='cebraspe_novos')

# %%
import os
from pathlib import Path

# %%
Path(os.getenv("PATH_DATA")) / os.getenv("PATH_DB_NOTICIAS")
# Out:
# PosixPath('/workspace/data/noticias')
